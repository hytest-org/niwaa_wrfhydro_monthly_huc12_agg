# %%
import xarray as xr

# %%
lesfinal= xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/final_out/fresh/huc12_monthly_wb_iwaa_wrfhydro_WY2011_2013.nc')
lesfinal
# Out:
# <xarray.Dataset> Size: 160MB
# Dimensions:                    (time: 35, huc_id: 86617)
# Coordinates:
#   * huc_id                     (huc_id) |S12 1MB b'010100020101' ... b'181002...
#   * time                       (time) datetime64[ns] 280B 2011-01-01 ... 2013...
# Data variables: (12/17)
#     yrmo                       (time) <U7 980B dask.array<chunksize=(35,), meta=np.ndarray>
#     CatchmentArea              (huc_id) float32 346kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     LandFraction               (huc_id) float32 346kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     total_gridded_area         (huc_id) float32 346kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     avgSOILM_wltadj_depthmean  (huc_id, time) float32 12MB dask.array<chunksize=(86617, 35), meta=np.ndarray>
#     avgSOILSAT_wltadj_top1     (huc_id, time) float32 12MB dask.array<chunksize=(86617, 35), meta=np.ndarray>
#     ...                         ...
# ...

# %%
ncarfinal= xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/tocompare/huc12_monthly_wrfhydro_conus404ba_WY2010_2021.nc')
ncarfinal
# Out:
# <xarray.Dataset> Size: 654MB
# Dimensions:                    (time: 144, huc_id: 86617)
# Coordinates:
#   * huc_id                     (huc_id) <U12 4MB '010100020101' ... '17100106...
#   * time                       (time) datetime64[ns] 1kB 2009-10-01 ... 2021-...
# Data variables: (12/17)
#     yrmo                       (time) <U7 4kB dask.array<chunksize=(144,), meta=np.ndarray>
#     CatchmentArea              (huc_id) float32 346kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     LandFraction               (huc_id) float32 346kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     total_gridded_area         (huc_id) float64 693kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     avgSOILM_wltadj_depthmean  (huc_id, time) float32 50MB dask.array<chunksize=(86617, 144), meta=np.ndarray>
#     avgSOILSAT_wltadj_top1     (huc_id, time) float32 50MB dask.array<chunksize=(86617, 144), meta=np.ndarray>
#     ...                         ...
# ...

# %%
soil= xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/static_niwaa_wrf_hydro_files/WRFHydro_soil_properties_CONUS_1km_NIWAAv1.0.nc')

# %%
soil
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:                  (Time: 1, south_north: 3840, west_east: 4608,
#                               soil_layers_stag: 4)
# Dimensions without coordinates: Time, south_north, west_east, soil_layers_stag
# Data variables: (12/28)
#     scamax                   (Time, south_north, west_east) float32 71MB dask.array<chunksize=(1, 3840, 4608), meta=np.ndarray>
#     rsurfsnow                (Time, south_north, west_east) float32 71MB dask.array<chunksize=(1, 3840, 4608), meta=np.ndarray>
#     tau0                     (Time, south_north, west_east) float32 71MB dask.array<chunksize=(1, 3840, 4608), meta=np.ndarray>
#     snowretfac               (Time, south_north, west_east) float32 71MB dask.array<chunksize=(1, 3840, 4608), meta=np.ndarray>
#     ssi                      (Time, south_north, west_east) float32 71MB dask.array<chunksize=(1, 3840, 4608), meta=np.ndarray>
# ...

# %%
ds = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/tocompare/huc12_monthly_wrfhydro_conus404ba_WY2010_2021.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 654MB
# Dimensions:                    (time: 144, huc_id: 86617)
# Coordinates:
#   * huc_id                     (huc_id) <U12 4MB '010100020101' ... '17100106...
#   * time                       (time) datetime64[ns] 1kB 2009-10-01 ... 2021-...
# Data variables: (12/17)
#     yrmo                       (time) <U7 4kB dask.array<chunksize=(144,), meta=np.ndarray>
#     CatchmentArea              (huc_id) float32 346kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     LandFraction               (huc_id) float32 346kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     total_gridded_area         (huc_id) float64 693kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     avgSOILM_wltadj_depthmean  (huc_id, time) float32 50MB dask.array<chunksize=(86617, 144), meta=np.ndarray>
#     avgSOILSAT_wltadj_top1     (huc_id, time) float32 50MB dask.array<chunksize=(86617, 144), meta=np.ndarray>
#     ...                         ...
# ...

# %%
ds = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/agg_out/CONUS_HUC12_WB_2D_19791001_20220930_2.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 89MB
# Dimensions:                    (WBDHU12: 86604, time: 12)
# Coordinates:
#   * WBDHU12                    (WBDHU12) int64 693kB 10100020101 ... 18100204...
#   * time                       (time) datetime64[ns] 96B 2011-10-01 ... 2012-...
# Data variables: (12/17)
#     total_gridded_area         (WBDHU12) float64 693kB dask.array<chunksize=(86604,), meta=np.ndarray>
#     Precip                     (WBDHU12, time) float32 4MB dask.array<chunksize=(86604, 12), meta=np.ndarray>
#     landmask                   (WBDHU12) float64 693kB dask.array<chunksize=(86604,), meta=np.ndarray>
#     deltaACCET                 (WBDHU12, time) float64 8MB dask.array<chunksize=(86604, 12), meta=np.ndarray>
#     deltaACSNOW                (WBDHU12, time) float64 8MB dask.array<chunksize=(86604, 12), meta=np.ndarray>
#     deltaSNEQV                 (WBDHU12, time) float32 4MB dask.array<chunksize=(86604, 12), meta=np.ndarray>
#     ...                         ...
# ...

# %%
ds = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/subset_GWOUT_mo/gw_201311.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 78MB
# Dimensions:       (feature_id: 2776734)
# Coordinates:
#   * feature_id    (feature_id) int64 22MB 6635572 6635590 ... 25293410 15450136
# Data variables:
#     totOutflow    (feature_id) float32 11MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     totInflow     (feature_id) float32 11MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     deltaDepth    (feature_id) float64 22MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     bucket_depth  (feature_id) float32 11MB dask.array<chunksize=(925578,), meta=np.ndarray>
# Attributes:
#     history:  Tue Mar 25 14:35:49 2025: ncap2 -O -s outflow=float(outflow*360...
#     NCO:      netCDF Operators version 5.2.9 (Homepage = http://nco.sf.net, C...

# %%
ds = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/subset_CHRTOUT_hr/2011/201112312300.CHRTOUT_DOMAIN1')

# %%
ds
# Out:
# <xarray.Dataset> Size: 200MB
# Dimensions:         (feature_id: 2776734, time: 1, reference_time: 1)
# Coordinates:
#   * time            (time) datetime64[ns] 8B 2011-12-31T23:00:00
#   * reference_time  (reference_time) datetime64[ns] 8B 2011-12-01
#   * feature_id      (feature_id) int64 22MB 101 179 ... 1180001803 1180001804
#     latitude        (feature_id) float32 11MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     longitude       (feature_id) float32 11MB dask.array<chunksize=(925578,), meta=np.ndarray>
# Data variables:
#     qBtmVertRunoff  (feature_id) float64 22MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     qBucket         (feature_id) float64 22MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     qSfcLatRunoff   (feature_id) float64 22MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     q_lateral       (feature_id) float64 22MB dask.array<chunksize=(925578,), meta=np.ndarray>
# ...

# %%
ds = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/subset_CHRTOUT_mo/chrt_201312.nc')
ds
# Out:
# /home/lstaub/miniforge3/envs/wrfhydro_huc12_agg/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'totqBucket' has multiple fill values {-999900000, -999900000.0} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /home/lstaub/miniforge3/envs/wrfhydro_huc12_agg/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'totqSfcLatRunoff' has multiple fill values {-999900000, -999900000.0} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# <xarray.Dataset> Size: 78MB
# Dimensions:           (feature_id: 2776734)
# Coordinates:
#   * feature_id        (feature_id) int64 22MB 101 179 ... 1180001803 1180001804
#     latitude          (feature_id) float32 11MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     longitude         (feature_id) float32 11MB dask.array<chunksize=(925578,), meta=np.ndarray>
# Data variables:
# ...

# %%
ds = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/subset_CHRTOUT_hr/2011/201112312300.CHRTOUT_DOMAIN1')

# %%
ncar = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/tocompare/huc12_monthly_wrfhydro_conus404ba_WY2010_2021.nc')

# %%
ncar
# Out:
# <xarray.Dataset> Size: 654MB
# Dimensions:                    (time: 144, huc_id: 86617)
# Coordinates:
#   * huc_id                     (huc_id) <U12 4MB '010100020101' ... '17100106...
#   * time                       (time) datetime64[ns] 1kB 2009-10-01 ... 2021-...
# Data variables: (12/17)
#     yrmo                       (time) <U7 4kB dask.array<chunksize=(144,), meta=np.ndarray>
#     CatchmentArea              (huc_id) float32 346kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     LandFraction               (huc_id) float32 346kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     total_gridded_area         (huc_id) float64 693kB dask.array<chunksize=(86617,), meta=np.ndarray>
#     avgSOILM_wltadj_depthmean  (huc_id, time) float32 50MB dask.array<chunksize=(86617, 144), meta=np.ndarray>
#     avgSOILSAT_wltadj_top1     (huc_id, time) float32 50MB dask.array<chunksize=(86617, 144), meta=np.ndarray>
#     ...                         ...
# ...

# %%
ds = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/subset_LDASOUT_mo/water_201312.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:                    (time: 1, y: 3840, x: 4608, soil_layers_stag: 4)
# Coordinates:
#   * time                       (time) datetime64[ns] 8B 2013-12-16T10:30:00
#   * x                          (x) float64 37kB -2.303e+06 ... 2.304e+06
#   * y                          (y) float64 31kB -1.92e+06 ... 1.919e+06
# Dimensions without coordinates: soil_layers_stag
# Data variables: (12/13)
#     deltaACCET                 (time, y, x) float32 71MB dask.array<chunksize=(1, 768, 922), meta=np.ndarray>
#     deltaACSNOW                (time, y, x) float32 71MB dask.array<chunksize=(1, 768, 922), meta=np.ndarray>
#     deltaSNEQV                 (time, y, x) float32 71MB dask.array<chunksize=(1, 768, 922), meta=np.ndarray>
#     deltaSOILM                 (time, y, soil_layers_stag, x) float32 283MB dask.array<chunksize=(1, 768, 1, 922), meta=np.ndarray>
# ...
