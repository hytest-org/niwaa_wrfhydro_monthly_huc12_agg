# %%
import xarray as xr

# %%
ds = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/subset_GWOUT_hr/2011/201112312300.GWOUT_DOMAIN1')

# %%
ds = xr.open_mfdataset('/caldera/hovenweep/projects/usgs/water/impd/hytest/working/niwaa_wrfhydro_monthly_huc12_aggregations/subset_GWOUT_mo_OLD/gw_201101.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 89MB
# Dimensions:         (feature_id: 2776734, time: 1, reference_time: 1)
# Coordinates:
#   * time            (time) datetime64[ns] 8B 2011-12-31T23:00:00
#   * reference_time  (reference_time) datetime64[ns] 8B 2011-12-01
#   * feature_id      (feature_id) int64 22MB 6635572 6635590 ... 15450136
# Data variables:
#     inflow          (feature_id) float64 22MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     outflow         (feature_id) float64 22MB dask.array<chunksize=(925578,), meta=np.ndarray>
#     depth           (feature_id) float64 22MB dask.array<chunksize=(925578,), meta=np.ndarray>
# Attributes:
#     TITLE:                      OUTPUT FROM WRF-Hydro v5.2.0
#     featureType:                timeSeries
#     model_initialization_time:  2011-12-01_00:00:00
#     station_dimension:          gw_id
#     model_output_valid_time:    2011-12-31_23:00:00
#     model_total_valid_times:    2232
#     Conventions:                CF-1.6
# ...
